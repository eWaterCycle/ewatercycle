# %%
# Suppress distracting outputs in these examples
# Note: this cell should be hidden with the tag "hide-cell"
import logging
import warnings

from rich import print

warnings.filterwarnings("ignore", category=UserWarning)
logger = logging.getLogger("esmvalcore")
logger.setLevel(logging.WARNING)

# %% [markdown]
# # Parameter sets
#
# Parameter sets are an essential part of many hydrological models, and for the eWaterCycle package as well.

# %%
import ewatercycle.parameter_sets

# %% [markdown]
# The default [system setup](https://ewatercycle.readthedocs.io/en/latest/system_setup.html#download-example-parameter-sets) includes a number of example parameter sets that can be used directly. System administrators can also add available parameter sets that are globally availble to all users. In the future, we're hoping to add functionality to fetch new parameter sets using a DOI as well.
#
# To see the available parameter sets:

# %%
sets = ewatercycle.parameter_sets.available_parameter_sets()
print(sets)
# Out:
# {
#     'lisflood_fraser': ParameterSet(
#         name='lisflood_fraser',
#         directory=PosixPath('/data/shared/parameter-sets/lisflood_fraser'),
#         config=PosixPath('/data/shared/parameter-sets/lisflood_fraser/settings_lat_lon-Run.xml'),
#         doi='N/A',
#         target_model='lisflood',
#         supported_model_versions={'20.10'},
#         downloader=None
#     ),
#     'pcrglobwb_rhinemeuse_30min': ParameterSet(
#         name='pcrglobwb_rhinemeuse_30min',
#         directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min'),
#         config=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min/setup_natural_test.ini'),
#         doi='https://doi.org/10.5281/zenodo.1045339',
#         target_model='pcrglobwb',
#         supported_model_versions={'setters'},
#         downloader=None
#     ),
#     'wflow_rhine_sbm_nc': ParameterSet(
#         name='wflow_rhine_sbm_nc',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_rhine_sbm_nc'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_rhine_sbm_nc/wflow_sbm_NC.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Rhine_ERA5-calibrated': ParameterSet(
#         name='wflow_Rhine_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Great-Kei_ERA5-calibrated': ParameterSet(
#         name='wflow_Great-Kei_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Doring_ERA5-calibrated': ParameterSet(
#         name='wflow_Doring_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Doring_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Doring_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Merrimack_ERA5-calibrated': ParameterSet(
#         name='wflow_Merrimack_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Meuse_ERA5-calibrated': ParameterSet(
#         name='wflow_Meuse_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_rhine_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_rhine_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA-Interim-calibrated/wflow_sbm_era-interim.ini'
# ),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Savannah_ERA-Interim-calibrated': ParameterSet(
#         name='wflow_Savannah_ERA-Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Savannah_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Savannah_ERA-Interim-calibrated/wflow_sbm_era-interim.i
# ni'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Great-Kei_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_Great-Kei_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA-Interim-calibrated/wflow_sbm_era-interim.
# ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Merrimack_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_Merrimack_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA-Interim-calibrated/wflow_sbm_era-interim.
# ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Meuse_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_Meuse_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA-Interim-calibrated/wflow_sbm_era-interim.ini'
# ),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'lisflood_global-masked_01degree': ParameterSet(
#         name='lisflood_global-masked_01degree',
#         directory=PosixPath('/data/shared/parameter-sets/lisflood_global-masked_01degree'),
#         config=PosixPath('/data/shared/parameter-sets/lisflood_global-masked_01degree/settings_lisflood_ERA5.xml'),
#         doi='N/A',
#         target_model='lisflood',
#         supported_model_versions={'20.10'},
#         downloader=None
#     ),
#     'pcrglobwb_merrimack_05min': ParameterSet(
#         name='pcrglobwb_merrimack_05min',
#         directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_global'),
#         config=PosixPath('/data/shared/parameter-sets/pcrglobwb_global/merrimack_05min_era5.ini'),
#         doi='https://doi.org/10.5281/zenodo.1045339',
#         target_model='pcrglobwb',
#         supported_model_versions={'setters'},
#         downloader=None
#     ),
#     'pcrglobwb_rhine_05min': ParameterSet(
#         name='pcrglobwb_rhine_05min',
#         directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_global'),
#         config=PosixPath('/data/shared/parameter-sets/pcrglobwb_global/rhine_05min_era5.ini'),
#         doi='https://doi.org/10.5281/zenodo.1045339',
#         target_model='pcrglobwb',
#         supported_model_versions={'setters'},
#         downloader=None
#     ),
#     'wflow_merrimack_techpaper': ParameterSet(
#         name='wflow_merrimack_techpaper',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_merrimack_techpaper'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_merrimack_techpaper/wflow_sbm_era5_test.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_humber': ParameterSet(
#         name='wflow_humber',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_humber'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_humber/wflow_sbm.toml'),
#         doi='N/A',
#         target_model='wflowjl',
#         supported_model_versions=set(),
#         downloader=None
#     ),
#     'sfincs_humber': ParameterSet(
#         name='sfincs_humber',
#         directory=PosixPath('/data/shared/parameter-sets/sfincs_humber'),
#         config=PosixPath('/data/shared/parameter-sets/sfincs_humber/sfincs.inp'),
#         doi='N/A',
#         target_model='sfincs',
#         supported_model_versions=set(),
#         downloader=None
#     )
# }

# %% [markdown]
# Since most parameter sets are model specific, you can filter the results as well:

# %%
sets = ewatercycle.parameter_sets.available_parameter_sets(target_model="wflow")
print(sets)
# Out:
# {
#     'wflow_rhine_sbm_nc': ParameterSet(
#         name='wflow_rhine_sbm_nc',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_rhine_sbm_nc'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_rhine_sbm_nc/wflow_sbm_NC.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Rhine_ERA5-calibrated': ParameterSet(
#         name='wflow_Rhine_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Great-Kei_ERA5-calibrated': ParameterSet(
#         name='wflow_Great-Kei_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Doring_ERA5-calibrated': ParameterSet(
#         name='wflow_Doring_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Doring_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Doring_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Merrimack_ERA5-calibrated': ParameterSet(
#         name='wflow_Merrimack_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Meuse_ERA5-calibrated': ParameterSet(
#         name='wflow_Meuse_ERA5-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA5-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA5-calibrated/wflow_sbm_era5.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_rhine_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_rhine_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Rhine_ERA-Interim-calibrated/wflow_sbm_era-interim.ini'
# ),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Savannah_ERA-Interim-calibrated': ParameterSet(
#         name='wflow_Savannah_ERA-Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Savannah_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Savannah_ERA-Interim-calibrated/wflow_sbm_era-interim.i
# ni'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Great-Kei_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_Great-Kei_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Great-Kei_ERA-Interim-calibrated/wflow_sbm_era-interim.
# ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Merrimack_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_Merrimack_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Merrimack_ERA-Interim-calibrated/wflow_sbm_era-interim.
# ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_Meuse_ERA_Interim-calibrated': ParameterSet(
#         name='wflow_Meuse_ERA_Interim-calibrated',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA-Interim-calibrated'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_Meuse_ERA-Interim-calibrated/wflow_sbm_era-interim.ini'
# ),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     ),
#     'wflow_merrimack_techpaper': ParameterSet(
#         name='wflow_merrimack_techpaper',
#         directory=PosixPath('/data/shared/parameter-sets/wflow_merrimack_techpaper'),
#         config=PosixPath('/data/shared/parameter-sets/wflow_merrimack_techpaper/wflow_sbm_era5_test.ini'),
#         doi='N/A',
#         target_model='wflow',
#         supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#         downloader=None
#     )
# }

# %% [markdown]
# Once you have found a suitable parameter set, you can load it and see some more details:

# %%
parameter_set = sets["wflow_rhine_sbm_nc"]
print(parameter_set)
# Out:
# ParameterSet(
#     name='wflow_rhine_sbm_nc',
#     directory=PosixPath('/data/shared/parameter-sets/wflow_rhine_sbm_nc'),
#     config=PosixPath('/data/shared/parameter-sets/wflow_rhine_sbm_nc/wflow_sbm_NC.ini'),
#     doi='N/A',
#     target_model='wflow',
#     supported_model_versions={'2020.1.1', '2020.1.2', '2020.1.3'},
#     downloader=None
# )

# %% [markdown]
# or you can access individual attributes of the parameter sets

# %%
parameter_set.supported_model_versions
# Out:
# {'2020.1.1', '2020.1.2', '2020.1.3'}

# %% [markdown]
# Should you wish to configure your own parameter set (e.g. for PCRGlobWB in this case), this is also possible:

# %%
custom_parameter_set = ewatercycle.parameter_sets.ParameterSet(
    name="custom_parameter_set",
    directory="~/ewatercycle/docs/examples/parameter-sets/pcrglobwb_rhinemeuse_30min",
    config="~/ewatercycle/docs/examples/parameter-sets/pcrglobwb_rhinemeuse_30min/setup_natural_test.ini",
    target_model="pcrglobwb",
    doi="https://doi.org/10.5281/zenodo.1045339",
    supported_model_versions={"v0.2.1"},
)

# %% [markdown]
# <div class="alert alert-info">
#
# As you can see, an eWaterCycle parameter set is defined fully by a directory and a configuration file. The configuration file typically informs the model about the structure of the parameter set (e.g. "what is the filename of the land use data"). It is possible to change these settings later, when [setting up the model](03_models_obs_analysis.ipynb).
#
# </div>
